# %%
import pandas as pd

# %%
pwd
# Out:
# 'e:\\Udemy\\ML_DataScience\\pycrash'

# %%
ls
# Out:
#  Volume in drive E has no label.
#  Volume Serial Number is 0CCE-118E
#
#  Directory of e:\Udemy\ML_DataScience\pycrash
#
# 08/29/2021  05:12 PM    <DIR>          .
# 08/29/2021  05:12 PM    <DIR>          ..
# 07/23/2021  12:57 AM             8,308 crash_python.ipynb
# 07/12/2021  12:10 AM            27,815 numpy_exm.ipynb
# 07/23/2021  12:12 AM           143,794 pandas_data_frame.ipynb
# 08/29/2021  05:12 PM                 0 pandas_data_input_output.ipynb
# 08/26/2021  06:39 PM             4,961 pandas_date_time_method.ipynb
# 07/29/2021  12:17 AM            36,719 pandas_group_by_op.ipynb
# 08/25/2021  04:16 PM            11,856 pandas_merging_combine.ipynb
# 07/23/2021  01:56 AM            72,519 pandas_methos_statistical.ipynb
# 07/28/2021  11:45 PM            23,255 pandas_missing_data.ipynb
# 07/16/2021  12:56 AM             4,393 pandas_series.ipynb
# 08/25/2021  06:02 PM             9,711 pandas_text_data_manage.ipynb
# 07/07/2021  10:07 PM                 9 README.md
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'e:\\Udemy\\ML_DataScience\\pycrash'

# %%
df = pd.read_csv('D:/Download/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/hotel_booking_data.csv', index_col=0)

# %%
df
# Out:
#               is_canceled  lead_time  arrival_date_year arrival_date_month  \
# hotel
# Resort Hotel            0        342               2015               July
# Resort Hotel            0        737               2015               July
# Resort Hotel            0          7               2015               July
# Resort Hotel            0         13               2015               July
# Resort Hotel            0         14               2015               July
# ...                   ...        ...                ...                ...
# City Hotel              0         23               2017             August
# City Hotel              0        102               2017             August
# City Hotel              0         34               2017             August
# City Hotel              0        109               2017             August
# City Hotel              0        205               2017             August
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('D:/Download/UNZIP_FOR_NOTEBOOKS_FINAL/03-Pandas/movie_scores.csv')
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
df.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
df['pre_movie_score'].notnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: pre_movie_score, dtype: bool

# %%
# show the data frame with conditional filtering
df[df['pre_movie_score'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df[(df['pre_movie_score'].isnull() & df['first_name'].notnull())]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %%
# Keep data
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
# Drop data
drop_NA_df = df.dropna()
drop_NA_df
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
# Fill data
fill_value_df = df.fillna('New Value')
fill_value_df
# Out:
#   first_name  last_name        age        sex pre_movie_score post_movie_score
# 0        Tom      Hanks       63.0          m             8.0             10.0
# 1  New Value  New Value  New Value  New Value       New Value        New Value
# 2       Hugh    Jackman       51.0          m       New Value        New Value
# 3      Oprah    Winfrey       66.0          f             6.0              8.0
# 4       Emma      Stone       31.0          f             7.0              9.0
